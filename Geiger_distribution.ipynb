# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\SUN\Desktop\Geiger\Geiger_raw.csv','r',header=None)

# %%
array = np.array(df)/4

# %%
fig = plt.figure()
plt.violinplot(array)
plt.boxplot(array)
plt.show()
